# %%
import pandas as pd

df=pd.read_csv('Input.csv')
new_df=pd.read_json('output.json')

# %%
df
# Out:
#      URL_ID                                                URL
# 0        37  https://insights.blackcoffer.com/ai-in-healthc...
# 1        38  https://insights.blackcoffer.com/what-if-the-c...
# 2        39  https://insights.blackcoffer.com/what-jobs-wil...
# 3        40  https://insights.blackcoffer.com/will-machine-...
# 4        41  https://insights.blackcoffer.com/will-ai-repla...
# ..      ...                                                ...
# 109     146  https://insights.blackcoffer.com/blockchain-fo...
# 110     147  https://insights.blackcoffer.com/the-future-of...
# 111     148  https://insights.blackcoffer.com/big-data-anal...
# 112     149  https://insights.blackcoffer.com/business-anal...
# 113     150  https://insights.blackcoffer.com/challenges-an...
#
# [114 rows x 2 columns]

# %%
new_df
# Out:
#      URL_ID                                                URL  \
# 0        37  https://insights.blackcoffer.com/ai-in-healthc...
# 1        39  https://insights.blackcoffer.com/what-jobs-wil...
# 2        41  https://insights.blackcoffer.com/will-ai-repla...
# 3        38  https://insights.blackcoffer.com/what-if-the-c...
# 4        40  https://insights.blackcoffer.com/will-machine-...
# ..      ...                                                ...
# 106     148  https://insights.blackcoffer.com/big-data-anal...
# 107     149  https://insights.blackcoffer.com/business-anal...
# 108     150  https://insights.blackcoffer.com/challenges-an...
# 109     147  https://insights.blackcoffer.com/the-future-of...
# 110     139  https://insights.blackcoffer.com/industrial-re...
#
#                                                  title  \
# 0         AI in healthcare to Improve Patient Outcomes
# 1    What Jobs Will Robots Take From Humans in The ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   URL_ID  114 non-null    int64
#  1   URL     114 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 1.9+ KB

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   URL_ID                       111 non-null    int64
#  1   URL                          111 non-null    object
#  2   title                        111 non-null    object
#  3   body                         111 non-null    object
#  4   word_count                   111 non-null    int64
#  5   positive_score               111 non-null    int64
#  6   negative_score               111 non-null    int64
#  7   polarity_score               111 non-null    float64
#  8   subjectivity_score           111 non-null    float64
#  9   average_sentence_length      111 non-null    float64
#  10  average_words_per_sentence   111 non-null    float64
#  11  complex_words_count          111 non-null    int64
#  12  percentage_of_complex_words  111 non-null    float64
# ...

# %%
new_df.drop(columns=['title','body'])
# Out:
#      URL_ID                                                URL  word_count  \
# 0        37  https://insights.blackcoffer.com/ai-in-healthc...        1107
# 1        39  https://insights.blackcoffer.com/what-jobs-wil...         965
# 2        41  https://insights.blackcoffer.com/will-ai-repla...         910
# 3        38  https://insights.blackcoffer.com/what-if-the-c...         739
# 4        40  https://insights.blackcoffer.com/will-machine-...         817
# ..      ...                                                ...         ...
# 106     148  https://insights.blackcoffer.com/big-data-anal...         631
# 107     149  https://insights.blackcoffer.com/business-anal...         319
# 108     150  https://insights.blackcoffer.com/challenges-an...         559
# 109     147  https://insights.blackcoffer.com/the-future-of...         613
# 110     139  https://insights.blackcoffer.com/industrial-re...          88
#
# ...
